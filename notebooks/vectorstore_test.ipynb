# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_chunks
from app.vetorstore import build_vectorstore
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Load Chunks

# %%
chunks = load_chunks()

# %%
print(chunks[50].page_content)
# Out:
# Грин Карты — вида на жительство в США. Программа сертификата — профессиональное образование. Во время и по истечению программы выпускник может пройти оплачиваемую стажировку в американской компании по выбранной специализации. Что нужно для подачи заявки? Ваш возраст — от 17 до 65 лет Аттестат об окончании средней школы (11 классов) или его эквивалент Мы рекомендуем начать процесс подготовки за 3–6 месяцев до начала обучения Уровень владения английским языком не ниже уровня B2 (Upper Intermediate) Программа сертификата Аккредитована SEVP и признана ведущими работодателями по всему миру Сертификат по медицинской помощи Подробнее Управление электроникойи информационными системами Подробнее Анализ данных и работа с базами данных Подробнее Сертификат по управлению бизнес-технологиями и предпринимательству Подробнее Все направления Управление электроникой и информационными системами Цена: $1 364 в месяцГород: Сиэтл, ВашингтонНаправление: Наука, Технологии, Инженерия и Математика

# %% [markdown]
# # Create Vetors Data Base Store

# %%
vectorstore = build_vectorstore(chunks)

vectorstore
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ru-en-RoSBERTa
# Key                 | Status  |
# --------------------+---------+-
# pooler.dense.bias   | MISSING |
# pooler.dense.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
