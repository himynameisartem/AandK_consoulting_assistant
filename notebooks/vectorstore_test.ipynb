# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_chunks
from app.vetorstore import build_vectorstore
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Load Chunks

# %%
chunks = load_chunks()

# %%
print(chunks[50].page_content)
# Out:
# Кредитной картой (Visa, Mas ercard) через Робокассу
#
# CloudPaymen s
#  Заполните поле n адрес n n n Оплатить Заполните поле n адрес n n n

# %% [markdown]
# # Create Vetors Data Base Store

# %%
vectorstore = build_vectorstore(chunks)

vectorstore
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ru-en-RoSBERTa
# Key                 | Status  |
# --------------------+---------+-
# pooler.dense.bias   | MISSING |
# pooler.dense.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
