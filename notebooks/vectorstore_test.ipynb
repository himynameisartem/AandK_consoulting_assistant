# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_chunks
from app.vetorstore import build_vectorstore
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Load Chunks

# %%
chunks = load_chunks()

# %%
print(chunks[50].page_content)
# Out:
# бесплатную консультацию по визовому сопровождению и планированию поездки Забронировать консультацию Бинго счастливого обладателя визы B1/B2 Отправиться на шопинг Погрузитесь в мир шопинга и порадуйте себя покупками в лучших магазинах и аутлетах Америки. Найдите уникальные товары и сделайте выгодные приобретения с помощью A&KЗабронируйте бесплатную консультацию по визовому сопровождению и планированию поездки Забронировать консультацию Бинго счастливого обладателя визы B1/B2 Посещение запуска

# %% [markdown]
# # Create Vetors Data Base Store

# %%
vectorstore = build_vectorstore(chunks)

vectorstore
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ru-en-RoSBERTa
# Key                 | Status  |
# --------------------+---------+-
# pooler.dense.weight | MISSING |
# pooler.dense.bias   | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
