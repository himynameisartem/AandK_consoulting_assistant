# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_chunks
from app.vetorstore import build_vectorstore
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Load Chunks

# %%
chunks = load_chunks()

# %%
print(chunks[50].page_content)
# Out:
# или спонсораПисьмо от спонсора в форме учебного заведения (если есть спонсор)Сертификат владения английским языкомДля F-2Супруг(а):Скан паспортаСвидетельство о браке, оригинал + переводДети:Скан паспортаСвидетельство о рождении, оригинал + переводДаты начала:2 января1 апреля24 июня23 сентябряP.S. Если вам нужна помощь, не стесняйтесь обращаться к нам. Мы всегда рады помочь людям достигнуть своих целей. Воплощайте свои мечты в жизнь! Подать заявку Управление электроникой и информационными системами Заполните форму, и мы с вами свяжемся в течение дня Выбор предпочитаемого способа связи Wha sapp Telegram Мною прочитаны и принятыусловия политики конфиденциальности Заполните поле n адрес n n n n Заполните поле n адрес n n n Анализ данных и работа с базами данных Цена: $1 586 в месяцГород: Сиэтл, ВашингтонНаправление: Наука, Технологии, Инженерия и Математика (STEM)Минимальный возраст: от 16 летМинимальная сумма на счете за минимальный период обучения: от $26 700Продолжительность: 12

# %% [markdown]
# # Create Vetors Data Base Store

# %%
vectorstore = build_vectorstore(chunks)

vectorstore
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ru-en-RoSBERTa
# Key                 | Status  |
# --------------------+---------+-
# pooler.dense.bias   | MISSING |
# pooler.dense.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
