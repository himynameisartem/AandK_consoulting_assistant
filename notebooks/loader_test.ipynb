# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_sitemap_docs, split_docs, save_chunks, load_recursive_sitemap, clean_docs
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Download

# %%
sitemap_docs = load_sitemap_docs()
print(len(sitemap_docs))
# Out:
# Fetching pages: 100%|##########| 386/386 [01:06<00:00,  5.81it/s]
# 386

# %%
recursive_docs = load_recursive_sitemap()
print(len(recursive_docs))
# Out:
# 18

# %%
docs = sitemap_docs + recursive_docs

# %%
docs = clean_docs(docs)
print(len(docs))
# Out:
# 340

# %% [markdown]
# # Text Splittters

# %%
chunks = split_docs(docs)
print(len(chunks))
# Out:
# 2291

# %%
print(chunks[0].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[1].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[100].page_content.replace('\n', ' '))
# Out:
# Самый легкий способ выучить английский язык в США A&K RU Визы Журнал Контакты Программы Оценка шансов Услуги Студенческая виза в США Туристическая виза в США Шенгенская виза Университетские программы Языковые курсы English Русский Главная Оценка шансов на получение визы Услуги Языковые курсы Университетские программы Студенческая виза Туристическая виза Журнал Контакты ⭐ Green Card и свободно заговорить на английском языке n Самый доступныйспособ приехать в США Подходит для людейот 15 до 75 лет Помогаем с адаптацией и строим комьюнити 7+ лет опытаБолее 10 000 клиентов 🇺🇸 Учатся и путешествуют с друзьями или семьей 👨‍👩‍👧 ✈️ Посещают другие страны, пока действует виза 🏠 Арендуют дома, квартиры и комнаты без кредитной истории и SSN Клиенты А&К в США 🇺🇸 Получают гринкарту при появлении оснований Получают SSN и временное разрешение на работу после окончания программы сертификата 💼 🩺 Оформляют медицинскую страховку 💸 Открывают бизнес и получают дивиденды 🐶 Заводят домашних питомцев или
# ---------------------------------------
# Получают SSN и временное разрешение на работу после окончания программы сертификата 💼 🩺 Оформляют медицинскую страховку 💸 Открывают бизнес и получают дивиденды 🐶 Заводят домашних питомцев или привозят их с родины 💳 Оформляют дебетовые и кредитные карты американских банков Получают местные права и арендуют или приобретают автомобили 🚘 Бесплатный гайд n Все о самом доступном способе приехать в США и прокачать английский язык в 2025 году 1. Кому подойдет этот способ? 2. Какие преимущества он дает? 3. Как выбрать город для жизни в США? 4. Как подготовиться к поездке в Америку? 5. Сколько денег нужно на старте? Знакомьтесь, тот самый способ Важные факты про F-1 Доступна для людей в возрасте 15 - 75 лет.Можно получить в течение 1−3 месяцев.Можно получить в пустой паспорт.Подойдет и тем, кто не знает английский.Статус можно продлевать на любой срок обучения. Встречайте, виза F-1 Виза иностранного студента подходит не только тем, кто недавно окончил школу, или стремится получить академическую
# ---------------------------------------
# u044e u043f u0440 u043e u0447 u0438 u0442 u0430 u043d u044b u0438 u043f u0440 u0438 u043d u044f u0442 u044b u0443 u0441 u043b u043e u0432 u0438 u044f u043f u043e u043b u0438 u0442 u0438 u043a u0438 u043a u043e u043d u0444 u0438 u0434 u0435 u043d u0446 u0438 u0430 u043b u044c u043d u043e u0441 u0442 u0438< /a>","li_nm":"Checkbox"}] Вы на этапе выбора Базовое сопровождение Заполните форму и наш менеджер свяжется с вами Закрыть [{"lid":"1531306243545","ls":"10","loff":"","li_ ype":"nm","li_ph":" u0418 u043c u044f","li_req":"y","li_nm":"Name"},{"lid":"1687871934402","ls":"20","loff":"","li_ ype":"ph","li_ph":"+7 999 999 99 99 ","li_req":"y","li_mask ype":"a","li_nm":"Phone"},{"lid":"1691549309017","ls":"30","loff":"","li_ ype":"in","li_ph":"@ u043d u0438 u043a u0432 elegram ( u043d u0435 u043e u0431 u044f u0437 u0430 u0442 u0435 u043b u044c u043d u043e)","li_nm":"Inpu "},{"lid":"1687871972993","ls":"40","loff":"","li_

# %% [markdown]
# # Save Chunks

# %%
save_chunks(chunks)
