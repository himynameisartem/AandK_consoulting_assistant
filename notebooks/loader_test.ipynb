# %%
import os
from  langchain_community.document_loaders import WebBaseLoader

# %%
os.environ["USER_AGENT"] = "Mozilla/5.0"

# %% [markdown]
# # Download

# %%
loader = WebBaseLoader('https://us-ak.com/services')
docs = loader.load()

# %%
print(f"Found {len(docs)} documents")
print(f"Total characters: {sum(len(doc.page_content) for doc in docs)}")
# Out:
# Found 1 documents
# Total characters: 15208

# %% [markdown]
# # Text Splittters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# %%
print(splits[0].page_content.replace('\n', ' '))
print("---------------------------------------")
print(splits[1].page_content.replace('\n', ' '))
print("---------------------------------------")
print(splits[2].page_content.replace('\n', ' '))
# Out:
# Все услуги компании American Educational Consulting | A&K                                                                                                                                                A&K                                                                                                           RU               Визы                                                Журнал   Контакты   Программы                                                Оценка шансов   Услуги                   Студенческая виза в США   Туристическая виза в США   Шенгенская виза                   Университетские программы   Языковые курсы                   English        Русский                                                                                                               Главная   Оценка шансов на получение визы   Услуги   Языковые курсы   Университетские программы   Студенческая виза   Туристическая виза   Журнал   Контакты   ⭐ Green Card
# ---------------------------------------
# шансов на получение визы   Услуги   Языковые курсы   Университетские программы   Студенческая виза   Туристическая виза   Журнал   Контакты   ⭐ Green Card                                           Услуги компании                   Студенческая виза 🧑‍🎓        Туристическая виза ✈️️️        Шенгенская виза 🇪🇺                        В языковую школу        В университет                          Подробнее      -30% на второго и последующих сопровождающих   $2 000 первый взнос при оплате частями   $4 990   Для тех, кто ценит свое время       Комфортное и надежное решениес максимальным включением эксперта, круглосуточной поддержкойи консьерж-сопровождением в США.   в языковую школу   Премиумсопровождение   👑              Подробнее      -30% на второго и последующих сопровождающих   $1 100 первый взнос при оплате частями   $2 190   Для тех, кто настроен на победу       Эффективное решениедля организации процесса с оптимальным использованием средств и времени на протяжении всего пути.   в
# ---------------------------------------
# взнос при оплате частями   $2 190   Для тех, кто настроен на победу       Эффективное решениедля организации процесса с оптимальным использованием средств и времени на протяжении всего пути.   в языковую школу   Полноесопровождение   🔥     Бестселлер                 Подробнее      -30% на второго и последующих сопровождающих   $1 090   Для тех, кто уверен в своих силах       Решение для активных путешественников, готовых включаться в процесс получения визы, опираясь на профессиональную поддержку.   в языковую школу   Базовоесопровождение   ⭐️                        Премиумсопровождение   👑     Подробнее      Комфортное и надежное решениес максимальным включением эксперта, круглосуточной поддержкой,и консьерж-сопровождением в США.       в университет   -30% на второго и последующих сопровождающих   $5 490   $2 200 первый взнос при оплате частями   Для тех, кто ценит свое время       Полноесопровождение     Подробнее      🔥   Эффективное решениедля организации процесса с оптимальным

# %% [markdown]
# # Save Chunks

# %%
import pickle

# %%
with open ("../data/chunks.pickle", "wb") as f:
    pickle.dump(splits, f)
