# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_sitemap_docs, split_docs, save_chunks, load_recursive_sitemap, clean_docs
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Download

# %%
sitemap_docs = load_sitemap_docs()
print(len(sitemap_docs))
# Out:
# Fetching pages: 100%|##########| 386/386 [01:30<00:00,  4.28it/s]
# 386

# %%
recursive_docs = load_recursive_sitemap()
print(len(recursive_docs))
# Out:
# 18

# %%
docs = sitemap_docs + recursive_docs

# %%
docs = clean_docs(docs)
print(len(docs))
# Out:
# 337

# %%
chunks = split_docs(docs)
print(len(chunks))
# Out:
# 1893

# %%
print(chunks[0].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[1].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[100].page_content.replace('\n', ' '))
# Out:
# Новости и публикации | A&K A&K RU Визы Журнал Контакты Программы Оценка шансов Услуги n n n n n English Русский Главная Оценка шансов на получение визы Услуги n n Студенческая виза Туристическая виза Журнал Контакты ⭐ Green Card Журнал  Главная
# ---------------------------------------
# → Журнал How abou cookies? n в соответствии с пользовательским соглашением. Это нужно, чтобы улучшить ваш опыт использования сайта n n How abou cookies? Настройки Cookie Cookie необходимы для улучшения взаимодействия с сайтом n Всегда включены. Эти файлы cookie необходимы для того, чтобы вы могли использовать веб-сайт и его функции. Их нельзя отключить. Они устанавливаются в ответ на ваши действия, такие как настройка предпочтений конфиденциальности, вход в систему или заполнение форм. n Disabled Эти файлы cookie собирают информацию, чтобы помочь нам понять, как используются наши веб-сайты, насколько эффективны наши маркетинговые кампании, или чтобы помочь нам настроить наши веб-сайты для вас. Список используемых нами аналитических файлов cookie можно посмотреть здесь. n Disabled Эти файлы cookie предоставляют рекламным компаниям информацию о вашей онлайн-активности, чтобы помочь им показывать более релевантную онлайн-рекламу для вас или ограничить количество показов рекламы. Эта
# ---------------------------------------
# наши веб-сайты, насколько эффективны наши маркетинговые кампании, или чтобы помочь нам настроить наши веб-сайты для вас. Список используемых нами аналитических файлов cookie можно посмотреть здесь. n Disabled Эти файлы cookie предоставляют рекламным компаниям информацию о вашей онлайн-активности, чтобы помочь им показывать более релевантную онлайн-рекламу для вас или ограничить количество показов рекламы. Эта информация может быть передана другим рекламным компаниям. Список используемых нами рекламных файлов cookie можно посмотреть здесь. Подтвердить A&K American Educa ional Consul ing—официальный партнер образовательных учреждений в США и не предоставляет юридических услуг. Индивидуальные предприниматели Тишаев и Ливенцев сотрудничают с компанией в рамках соглашения. НАВИГАЦИЯ Главная n Программа сертификата Услуги Туристическая виза Студенческая виза Журнал ДОКУМЕНТЫ n n КОНТАКТЫ Подписаться Связаться office@usa-ak.com Copyrigh © 2026 A&K American Educa ional Consul ing. n. Wha sApp

# %% [markdown]
# # Save Chunks

# %%
save_chunks(chunks)
