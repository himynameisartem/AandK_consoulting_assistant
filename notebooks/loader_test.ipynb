# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_sitemap_docs, split_docs, save_chunks, clean_docs, load_recursive_sitemap
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from app import  loaders

# %% [markdown]
# # Download

# %%
sitemap_docs = load_sitemap_docs()
print(len(sitemap_docs))
# Out:
# Fetching pages: 100%|##########| 384/384 [02:02<00:00,  3.13it/s]
# 384

# %%
recursive_docs = load_recursive_sitemap()
print(len(recursive_docs))
# Out:
# 26

# %%
docs = sitemap_docs + recursive_docs

# %%
docs = clean_docs(docs)
print(len(docs))
# Out:
# 338

# %% [markdown]
# # Text Splittters

# %%
chunks = split_docs(docs)
print(len(chunks))
# Out:
# 2035

# %%
print(chunks[0].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[1].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[2].page_content.replace('\n', ' '))
# Out:
# Самый легкий способ выучить английский язык в США A&K RU Визы Журнал Контакты Программы Оценка шансов Услуги Студенческая виза в США Туристическая виза в США Шенгенская виза Университетские программы Языковые курсы English Русский Главная Оценка шансов на получение визы Услуги Языковые курсы Университетские программы Студенческая виза Туристическая виза Журнал Контакты ⭐ Green Card и свободно заговорить на английском языке
# ---------------------------------------
# ...

# %% [markdown]
# # Save Chunks

# %%
save_chunks(chunks)
