# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
from app.loaders import load_sitemap_docs, split_docs, save_chunks, load_recursive_sitemap, clean_docs
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Download

# %%
sitemap_docs = load_sitemap_docs()
print(len(sitemap_docs))
# Out:
# Fetching pages: 100%|##########| 386/386 [08:16<00:00,  1.29s/it]
# 386

# %%
recursive_docs = load_recursive_sitemap()
print(len(recursive_docs))
# Out:
# 18

# %%
docs = sitemap_docs + recursive_docs

# %%
docs = clean_docs(docs)
print(len(docs))
# Out:
# 339

# %% [markdown]
# # Text Splittters

# %%
chunks = split_docs(docs)
print(len(chunks))
# Out:
# 3926

# %%
print(chunks[0].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[1].page_content.replace('\n', ' '))
print("---------------------------------------")
print(chunks[100].page_content.replace('\n', ' '))
# Out:
# Самый легкий способ выучить английский язык в США A&K RU Визы Журнал Контакты Программы Оценка шансов Услуги Студенческая виза в США Туристическая виза в США Шенгенская виза Университетские программы Языковые курсы English Русский Главная Оценка шансов на получение визы Услуги Языковые курсы Университетские программы Студенческая виза Туристическая виза Журнал Контакты ⭐ Green Card и свободно заговорить на английском языке n Самый доступныйспособ приехать в США Подходит для людейот 15 до 75 лет
# ---------------------------------------
# на английском языке n Самый доступныйспособ приехать в США Подходит для людейот 15 до 75 лет Помогаем с адаптацией и строим комьюнити 7+ лет опытаБолее 10 000 клиентов 🇺🇸 Учатся и путешествуют с друзьями или семьей 👨‍👩‍👧 ✈️ Посещают другие страны, пока действует виза 🏠 Арендуют дома, квартиры и комнаты без кредитной истории и SSN Клиенты А&К в США 🇺🇸 Получают гринкарту при появлении оснований Получают SSN и временное разрешение на работу после окончания программы сертификата 💼 🩺 Оформляют
# ---------------------------------------
# из банка на английском языке на имя студента или спонсораПисьмо от спонсора в форме учебного заведения (если есть спонсор)Сертификат владения английским языкомДля F-2Супруг(а):Скан паспортаСвидетельство о браке, оригинал + переводДети:Скан паспорта;Свидетельство о рождении, оригинал + переводДаты начала:2 января1 апреля24 июня23 сентябряP.S. Если вам нужна помощь, не стесняйтесь обращаться к нам. Мы всегда рады помочь людям достигнуть своих целей. Воплощайте свои мечты в жизнь! Подать заявку

# %% [markdown]
# # Save Chunks

# %%
save_chunks(chunks)
